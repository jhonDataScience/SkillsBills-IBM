# %% [markdown]
# ## 🥇 Jonathan Lugo Procesamiento de Lenguaje Natural
# <div>
#     <img src="data:image/jpeg;base64,..." alt="image_description" style="width:30%">
# </div>

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from bs4 import BeautifulSoup
import urllib.request

# %%
# Definir la URL
url = 'https://librefinanciero.com'

# Configurar los encabezados HTTP, incluyendo un User-Agent
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'}

# Crear una solicitud con los encabezados personalizados
request = urllib.request.Request(url, headers=headers)

# Hacer la solicitud y obtener la respuesta
response = urllib.request.urlopen(request)

# Leer el contenido HTML de la página web
html = response.read()

# Limpiar el texto HTML capturado usando BeautifulSoup
soup = BeautifulSoup(html, "html5lib")
text = soup.get_text(strip=True)

# Imprimir el texto limpio
print(text)
# Out:
# 🥇Alcanza la Libertad Financiera y Retírate🥇 - 【Libre Financiero】{"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://librefinanciero.com/","url":"https://librefinanciero.com/","name":"🥇Alcanza la Libertad Financiera y Retírate🥇 - 【Libre Financiero】","isPartOf":{"@id":"https://librefinanciero.com/#website"},"about":{"@id":"https://librefinanciero.com/#/schema/person/eac2ac957f89526d68f1baa1de35a76b"},"primaryImageOfPage":{"@id":"https://librefinanciero.com/#primaryimage"},"image":{"@id":"https://librefinanciero.com/#primaryimage"},"thumbnailUrl":"https://librefinanciero.com/wp-content/uploads/2019/04/Cabecera-v3-jpg-1024x311.jpg","datePublished":"2019-03-29T20:59:50+00:00","dateModified":"2020-09-10T09:08:31+00:00","description":"¿Quieres alcanzar la Libertad Financiera y tener la vida que deseas? ⇨ Sí que se puede y en este blog encontrarás las respuestas✅","breadcrumb":{"@id":"https://librefinanciero.com/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{
# ...

# %%
#Crear tokens por palabras
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text,"spanish")
tokens=[word.lower() for word in tokens if word.isalpha()] # Remover los signos de puntuación
print(tokens)
# Out:
# ['la', 'libertad', 'financiera', 'y', 'context', 'https', 'graph', 'type', 'webpage', 'id', 'https', 'url', 'https', 'name', 'la', 'libertad', 'financiera', 'y', 'ispartof', 'id', 'https', 'website', 'about', 'id', 'https', 'primaryimageofpage', 'id', 'https', 'primaryimage', 'image', 'id', 'https', 'primaryimage', 'thumbnailurl', 'https', 'datepublished', 'datemodified', 'description', 'alcanzar', 'la', 'libertad', 'financiera', 'y', 'tener', 'la', 'vida', 'que', 'deseas', 'sí', 'que', 'se', 'puede', 'y', 'en', 'este', 'blog', 'encontrarás', 'las', 'breadcrumb', 'id', 'https', 'breadcrumb', 'inlanguage', 'potentialaction', 'type', 'readaction', 'target', 'https', 'type', 'imageobject', 'inlanguage', 'id', 'https', 'primaryimage', 'url', 'https', 'contenturl', 'https', 'type', 'breadcrumblist', 'id', 'https', 'breadcrumb', 'itemlistelement', 'type', 'listitem', 'position', 'name', 'home', 'type', 'website', 'id', 'https', 'website', 'url', 'https', 'name', 'financiero', 'alcanza', 'l
# ...

# %%
#Verificar frecuencia de palabras 
freq = nltk.FreqDist(tokens)
for key,val in freq.items():
    print (str(key) + ':' + str(val))
# Out:
# la:509
# libertad:79
# financiera:94
# y:305
# context:1
# https:38
# graph:1
# type:12
# webpage:1
# id:15
# url:9
# name:5
# ispartof:1
# website:3
# about:1
# primaryimageofpage:1
# primaryimage:3
# image:2
# thumbnailurl:1
# datepublished:1
# datemodified:1
# description:2
# alcanzar:44
# tener:46
# vida:34
# que:734
# deseas:2
# sí:29
# se:92
# puede:23
# en:526
# este:128
# blog:17
# encontrarás:3
# las:115
# breadcrumb:3
# inlanguage:4
# potentialaction:2
# readaction:1
# target:2
# imageobject:2
# contenturl:2
# breadcrumblist:1
# itemlistelement:1
# listitem:1
# position:3
# home:3
# financiero:15
# alcanza:3
# independencia:29
# publisher:1
# searchaction:1
# entrypoint:1
# urltemplate:1
# required:1
# person:1
# organization:1
# width:5
# height:2
# caption:1
# logo:1
# cdata:8
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# source:1
# concatemoji:1
# this:43
# file:10
# is:6
# function:24
# i:9
# n:12
# var:74
# o:60
# s:6
# e:42
# c:6
# try:4
# supporttests:1
# timestamp:1
# ...

# %%
#Visualizar Tokens
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 2. Eliminar Palabras de Parada

# %%
from nltk.corpus import stopwords

clean_tokens = tokens[:]
 
for token in tokens:
 
    if token in stopwords.words('spanish'):
 
        clean_tokens.remove(token)

# %%
print(clean_tokens)
# Out:
# ['libertad', 'financiera', 'context', 'https', 'graph', 'type', 'webpage', 'id', 'https', 'url', 'https', 'name', 'libertad', 'financiera', 'ispartof', 'id', 'https', 'website', 'about', 'id', 'https', 'primaryimageofpage', 'id', 'https', 'primaryimage', 'image', 'id', 'https', 'primaryimage', 'thumbnailurl', 'https', 'datepublished', 'datemodified', 'description', 'alcanzar', 'libertad', 'financiera', 'tener', 'vida', 'deseas', 'puede', 'blog', 'encontrarás', 'breadcrumb', 'id', 'https', 'breadcrumb', 'inlanguage', 'potentialaction', 'type', 'readaction', 'target', 'https', 'type', 'imageobject', 'inlanguage', 'id', 'https', 'primaryimage', 'url', 'https', 'contenturl', 'https', 'type', 'breadcrumblist', 'id', 'https', 'breadcrumb', 'itemlistelement', 'type', 'listitem', 'position', 'name', 'home', 'type', 'website', 'id', 'https', 'website', 'url', 'https', 'name', 'financiero', 'alcanza', 'independencia', 'description', 'publisher', 'id', 'https', 'potentialaction', 'type', 'searc
# ...

# %%
#Verificar frecuencia de palabras 
freq_clean = nltk.FreqDist(clean_tokens)
for key,val in freq_clean.items():
    print (str(key) + ':' + str(val))
# Out:
# libertad:79
# financiera:94
# context:1
# https:38
# graph:1
# type:12
# webpage:1
# id:15
# url:9
# name:5
# ispartof:1
# website:3
# about:1
# primaryimageofpage:1
# primaryimage:3
# image:2
# thumbnailurl:1
# datepublished:1
# datemodified:1
# description:2
# alcanzar:44
# tener:46
# vida:34
# deseas:2
# puede:23
# blog:17
# encontrarás:3
# breadcrumb:3
# inlanguage:4
# potentialaction:2
# readaction:1
# target:2
# imageobject:2
# contenturl:2
# breadcrumblist:1
# itemlistelement:1
# listitem:1
# position:3
# home:3
# financiero:15
# alcanza:3
# independencia:29
# publisher:1
# searchaction:1
# entrypoint:1
# urltemplate:1
# required:1
# person:1
# organization:1
# width:5
# height:2
# caption:1
# logo:1
# cdata:8
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# source:1
# concatemoji:1
# this:43
# file:10
# is:6
# function:24
# i:9
# n:12
# var:74
# s:6
# c:6
# try:4
# supporttests:1
# timestamp:1
# new:5
# date:3
# t:21
# catch:3
# p:3
# return:11
# u:3
# switch:1
# case:2
# flag:3
# ...

# %%
#Visualizar Tokens
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq_clean.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 3a. Obtener Sinónimos

# %%
from nltk.corpus import wordnet
 
synonyms = []
 
for syn in wordnet.synsets('investment'):

    for lemma in syn.lemmas():
 
        synonyms.append(lemma.name())
 
print(synonyms)
# Out:
# ['investing', 'investment', 'investment', 'investment_funds', 'investment', 'investment', 'investment', 'investment', 'investiture']

# %%
#Reemplazar tokens sinónimos
for ind,sin in enumerate(synonyms):
    clean_tokens_sin = [word.replace(synonyms[ind],'investment') for word in clean_tokens]

# %%
#Reemplazar tokens sinónimos manual
sinonimos = ['libertad', 'independencia']
for ind,sin in enumerate(sinonimos):
    clean_tokens_sin = [word.replace(sinonimos[ind],'libertad') for word in clean_tokens]

# %%
#Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin = nltk.FreqDist(clean_tokens_sin)
for key,val in freq_clean_sin.items():
    print (str(key) + ':' + str(val))
# Out:
# libertad:108
# financiera:94
# context:1
# https:38
# graph:1
# type:12
# webpage:1
# id:15
# url:9
# name:5
# ispartof:1
# website:3
# about:1
# primaryimageofpage:1
# primaryimage:3
# image:2
# thumbnailurl:1
# datepublished:1
# datemodified:1
# description:2
# alcanzar:44
# tener:46
# vida:34
# deseas:2
# puede:23
# blog:17
# encontrarás:3
# breadcrumb:3
# inlanguage:4
# potentialaction:2
# readaction:1
# target:2
# imageobject:2
# contenturl:2
# breadcrumblist:1
# itemlistelement:1
# listitem:1
# position:3
# home:3
# financiero:15
# alcanza:3
# publisher:1
# searchaction:1
# entrypoint:1
# urltemplate:1
# required:1
# person:1
# organization:1
# width:5
# height:2
# caption:1
# logo:1
# cdata:8
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# source:1
# concatemoji:1
# this:43
# file:10
# is:6
# function:24
# i:9
# n:12
# var:74
# s:6
# c:6
# try:4
# supporttests:1
# timestamp:1
# new:5
# date:3
# t:21
# catch:3
# p:3
# return:11
# u:3
# switch:1
# case:2
# flag:3
# emoji:2
# f:1
# ...

# %%
#Visualizar Tokens
freq_clean_sin.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 3b. Obtener Antónimos

# %%
from nltk.corpus import wordnet
 
antonyms = []
 
for syn in wordnet.synsets("good"):
 
    for l in syn.lemmas():
 
        if l.antonyms():
 
            antonyms.append(l.antonyms()[0].name())
 
print(antonyms)
# Out:
# ['evil', 'evilness', 'bad', 'badness', 'bad', 'evil', 'ill']

# %% [markdown]
# # 4. Derivación Regresiva

# %%
from nltk.stem import PorterStemmer
 
stemmer = PorterStemmer()
 
print(stemmer.stem('eating'))
# Out:
# eat

# %%
#Derivación regresiva textos en español
from nltk.stem import SnowballStemmer
 
spanish_stemmer = SnowballStemmer('spanish')
 
print(spanish_stemmer.stem("trabajando"))
print(spanish_stemmer.stem("trabajo"))
# Out:
# trabaj
# trabaj

# %%
clean_tokens_sin_stems = [spanish_stemmer.stem(token) for token in clean_tokens_sin]

# %%
clean_tokens_sin_stems
# Out:
# ['libert',
#  'financ',
#  'context',
#  'https',
#  'graph',
#  'type',
#  'webpag',
#  'id',
#  'https',
#  'url',
#  'https',
#  'nam',
#  'libert',
#  'financ',
#  'ispartof',
#  'id',
#  'https',
#  'websit',
#  'about',
#  'id',
#  'https',
#  'primaryimageofpag',
#  'id',
#  'https',
#  'primaryimag',
#  'imag',
#  'id',
#  'https',
#  'primaryimag',
#  'thumbnailurl',
#  'https',
#  'datepublish',
#  'datemodifi',
#  'description',
#  'alcanz',
#  'libert',
#  'financ',
#  'ten',
#  'vid',
#  'des',
#  'pued',
#  'blog',
#  'encontr',
#  'breadcrumb',
#  'id',
#  'https',
#  'breadcrumb',
#  'inlanguag',
#  'potentialaction',
#  'type',
#  'readaction',
#  'target',
#  'https',
#  'type',
#  'imageobject',
#  'inlanguag',
#  'id',
#  'https',
#  'primaryimag',
#  'url',
#  'https',
#  'contenturl',
#  'https',
#  'type',
#  'breadcrumblist',
#  'id',
#  'https',
#  'breadcrumb',
#  'itemlistelement',
#  'type',
#  'listitem',
#  'position',
#  'nam',
#  'hom',
#  'type',
# ...

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin_stems = nltk.FreqDist(clean_tokens_sin_stems)
for key,val in freq_clean_sin_stems.items():
    print (str(key) + ':' + str(val))
# Out:
# libert:108
# financ:98
# context:1
# https:38
# graph:1
# type:12
# webpag:1
# id:15
# url:9
# nam:5
# ispartof:1
# websit:3
# about:1
# primaryimageofpag:1
# primaryimag:3
# imag:2
# thumbnailurl:1
# datepublish:1
# datemodifi:1
# description:2
# alcanz:62
# ten:49
# vid:34
# des:5
# pued:99
# blog:17
# encontr:7
# breadcrumb:3
# inlanguag:4
# potentialaction:2
# readaction:1
# target:2
# imageobject:2
# contenturl:2
# breadcrumblist:1
# itemlistelement:1
# listitem:1
# position:3
# hom:3
# financier:31
# publish:1
# searchaction:1
# entrypoint:1
# urltemplat:1
# requir:1
# person:35
# organization:1
# width:5
# height:2
# caption:1
# log:1
# cdat:8
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# sourc:1
# concatemoji:1
# this:43
# fil:12
# is:6
# function:24
# i:9
# n:12
# var:74
# s:6
# c:6
# try:4
# supporttests:1
# timestamp:1
# new:5
# dat:15
# t:21
# catch:3
# p:3
# return:11
# u:3
# switch:1
# cas:39
# flag:3
# emoji:2
# f:1
# undefin:6
# workerglobalscop:2
# self:1
# ...

# %%
#Visualizar Tokens
freq_clean_sin_stems.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 5. Lematizar palabras

# %%
from nltk.stem import WordNetLemmatizer
 
lemmatizer = WordNetLemmatizer()
 
print(lemmatizer.lemmatize('working', pos="v")) #sustantivos de manera predeterminada, especificar "v" si se quieren los verbos
# Out:
# work

# %%
import spacy

# %%
nlp = spacy.blank('ES')
#alternativa: nlp= spacy.load('es_core_news_md') #más información abajo

# %%
#Lematizar tokens tras limpieza y convertidos los sinónimos
clean_tokens_sin_lem = []
separator = ' '
for token in nlp(separator.join(clean_tokens_sin)): #Se juntan los tokens en una string, string es el formato necesario para nlp
    print(token.text, token.lemma_, token.pos_)
    clean_tokens_sin_lem.append(token.lemma_)
# Out:
# finanzas
# wikipedia
# enciclopedia
# libre
# function
# var
# var
# if
# cookie
# cookie
# function
# pref
# new
# regexp
# wgbreakframes
# false
# wgseparatortransformtable
# wgdigittransformtable
# wgdefaultdateformat
# dmy
# wgmonthnames
# enero
# febrero
# marzo
# abril
# mayo
# junio
# julio
# agosto
# septiembre
# octubre
# noviembre
# diciembre
# wgrequestid
# wgcanonicalnamespace
# wgcanonicalspecialpagename
# false
# wgnamespacenumber
# wgpagename
# finanzas
# wgtitle
# finanzas
# wgcurrevisionid
# wgrevisionid
# wgarticleid
# wgisarticle
# true
# wgisredirect
# false
# wgaction
# view
# wgusername
# null
# wgusergroups
# wgcategories
# wikipedia
# artículos
# necesitan
# referencias
# adicionales
# wikipedia
# referenciar
# aún
# clasificar
# wikipedia
# artículos
# identificadores
# lccn
# wikipedia
# artículos
# identificadores
# aat
# finanzas
# administración
# economía
# empresa
# wgpageviewlanguage
# wgpagecontentlanguage
# wgpagecontentmodel
# wikitext
# ...

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin_lem = nltk.FreqDist(clean_tokens_sin)
for key,val in freq_clean_sin_lem.items():
    print (str(key) + ':' + str(val))
# Out:
# finanzas:56
# wikipedia:9
# enciclopedia:2
# libre:1
# function:6
# var:17
# if:1
# cookie:2
# pref:1
# new:1
# regexp:1
# wgbreakframes:1
# false:11
# wgseparatortransformtable:1
# wgdigittransformtable:1
# wgdefaultdateformat:1
# dmy:1
# wgmonthnames:1
# enero:2
# febrero:1
# marzo:1
# abril:3
# mayo:6
# junio:3
# julio:1
# agosto:1
# septiembre:2
# octubre:3
# noviembre:1
# diciembre:1
# wgrequestid:1
# wgcanonicalnamespace:1
# wgcanonicalspecialpagename:1
# wgnamespacenumber:1
# wgpagename:1
# wgtitle:1
# wgcurrevisionid:1
# wgrevisionid:1
# wgarticleid:1
# wgisarticle:1
# true:13
# wgisredirect:1
# wgaction:1
# view:1
# wgusername:1
# null:1
# wgusergroups:1
# wgcategories:1
# artículos:6
# necesitan:2
# referencias:2
# adicionales:2
# referenciar:2
# aún:2
# clasificar:2
# identificadores:4
# lccn:1
# aat:1
# administración:5
# economía:14
# empresa:14
# wgpageviewlanguage:1
# wgpagecontentlanguage:1
# wgpagecontentmodel:1
# wikitext:1
# wgrelevantpagename:1
# ...

# %%
#Visualizar Tokens
freq_clean_sin_lem.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # Altenativa Spacy

# %%
nlp= spacy.load('es_core_news_sm')

# %%
clean_tokens_sin_lem=[]
palabras='comer comida comería comido comen'
for token in nlp(palabras): #Se juntan los tokens en una string, string es el formato necesario para nlp
    print(token.text, token.pos_)
    clean_tokens_sin_lem.append(token.lemma_)
    
print (clean_tokens_sin_lem)
clean_tokens_sin_lem=[]
# Out:
# comer VERB
# comida NOUN
# comería VERB
# comido ADJ
# comen NOUN
# ['comer', 'comida', 'comer', 'comido', 'comen']

# %% [markdown]
# ## Alternativa web https://es.wikipedia.org/wiki/Finanzas

# %%
# LEER TEXTO DESDE URL
  
response = urllib.request.urlopen('https://es.wikipedia.org/wiki/Finanzas') #Obtiene el contenido HTML de la página web http://librefinanciero.com/
 
html = response.read()
 
soup = BeautifulSoup(html,"html5lib") # Limpia el texto HTML capturado
 
text = soup.get_text(strip=True)
 
print (text)
# Out:
# Finanzas - Wikipedia, la enciclopedia libre(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )eswikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTrans
# ...

# %%
#Crear tokens por palabras
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text,"spanish")
tokens=[word.lower() for word in tokens if word.isalpha()] # Remover los signos de puntuación
print(tokens)
# Out:
# ['finanzas', 'wikipedia', 'la', 'enciclopedia', 'libre', 'function', 'var', 'var', 'if', 'cookie', 'cookie', 'function', 'pref', 'new', 'regexp', 'wgbreakframes', 'false', 'wgseparatortransformtable', 'wgdigittransformtable', 'wgdefaultdateformat', 'dmy', 'wgmonthnames', 'enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre', 'wgrequestid', 'wgcanonicalnamespace', 'wgcanonicalspecialpagename', 'false', 'wgnamespacenumber', 'wgpagename', 'finanzas', 'wgtitle', 'finanzas', 'wgcurrevisionid', 'wgrevisionid', 'wgarticleid', 'wgisarticle', 'true', 'wgisredirect', 'false', 'wgaction', 'view', 'wgusername', 'null', 'wgusergroups', 'wgcategories', 'wikipedia', 'artículos', 'que', 'necesitan', 'referencias', 'adicionales', 'wikipedia', 'referenciar', 'aún', 'sin', 'clasificar', 'wikipedia', 'artículos', 'con', 'identificadores', 'lccn', 'wikipedia', 'artículos', 'con', 'identificadores', 'aat', 'finanzas', 'administración', 
# ...

# %%
#Verificar frecuencia de palabras 
freq = nltk.FreqDist(tokens)
for key,val in freq.items():
    print (str(key) + ':' + str(val))
# Out:
# finanzas:56
# wikipedia:9
# la:118
# enciclopedia:2
# libre:1
# function:6
# var:17
# if:1
# cookie:2
# pref:1
# new:1
# regexp:1
# wgbreakframes:1
# false:11
# wgseparatortransformtable:1
# wgdigittransformtable:1
# wgdefaultdateformat:1
# dmy:1
# wgmonthnames:1
# enero:2
# febrero:1
# marzo:1
# abril:3
# mayo:6
# junio:3
# julio:1
# agosto:1
# septiembre:2
# octubre:3
# noviembre:1
# diciembre:1
# wgrequestid:1
# wgcanonicalnamespace:1
# wgcanonicalspecialpagename:1
# wgnamespacenumber:1
# wgpagename:1
# wgtitle:1
# wgcurrevisionid:1
# wgrevisionid:1
# wgarticleid:1
# wgisarticle:1
# true:13
# wgisredirect:1
# wgaction:1
# view:1
# wgusername:1
# null:1
# wgusergroups:1
# wgcategories:1
# artículos:6
# que:54
# necesitan:2
# referencias:2
# adicionales:2
# referenciar:2
# aún:2
# sin:4
# clasificar:2
# con:34
# identificadores:4
# lccn:1
# aat:1
# administración:5
# economía:14
# de:269
# empresa:14
# wgpageviewlanguage:1
# es:20
# wgpagecontentlanguage:1
# wgpagecontentmodel:1
# ...

# %%
#Visualizar Tokens
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from nltk.corpus import stopwords

clean_tokens = tokens[:]
 
for token in tokens:
 
    if token in stopwords.words('spanish'):
 
        clean_tokens.remove(token)

# %%
print(clean_tokens)
# Out:
# ['finanzas', 'wikipedia', 'enciclopedia', 'libre', 'function', 'var', 'var', 'if', 'cookie', 'cookie', 'function', 'pref', 'new', 'regexp', 'wgbreakframes', 'false', 'wgseparatortransformtable', 'wgdigittransformtable', 'wgdefaultdateformat', 'dmy', 'wgmonthnames', 'enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre', 'wgrequestid', 'wgcanonicalnamespace', 'wgcanonicalspecialpagename', 'false', 'wgnamespacenumber', 'wgpagename', 'finanzas', 'wgtitle', 'finanzas', 'wgcurrevisionid', 'wgrevisionid', 'wgarticleid', 'wgisarticle', 'true', 'wgisredirect', 'false', 'wgaction', 'view', 'wgusername', 'null', 'wgusergroups', 'wgcategories', 'wikipedia', 'artículos', 'necesitan', 'referencias', 'adicionales', 'wikipedia', 'referenciar', 'aún', 'clasificar', 'wikipedia', 'artículos', 'identificadores', 'lccn', 'wikipedia', 'artículos', 'identificadores', 'aat', 'finanzas', 'administración', 'economía', 'empresa', 'wgpageview
# ...

# %%
from nltk.corpus import wordnet
 
synonyms = []
 
for syn in wordnet.synsets('investment'):

    for lemma in syn.lemmas():
 
        synonyms.append(lemma.name())
 
print(synonyms)
# Out:
# ['investing', 'investment', 'investment', 'investment_funds', 'investment', 'investment', 'investment', 'investment', 'investiture']

# %%
#Reemplazar tokens sinónimos
for ind,sin in enumerate(synonyms):
    clean_tokens_sin = [word.replace(synonyms[ind],'investment') for word in clean_tokens]

# %%
from nltk.stem import PorterStemmer
 
#Derivación regresiva textos en español
from nltk.stem import SnowballStemmer
 
spanish_stemmer = SnowballStemmer('spanish')
 
print(spanish_stemmer.stem("trabajando"))
print(spanish_stemmer.stem("trabajo"))
stemmer = PorterStemmer()
clean_tokens_sin_stems = [spanish_stemmer.stem(token) for token in clean_tokens_sin]
# Out:
# trabaj
# trabaj

# %%
import spacy
nlp = spacy.blank('ES')
#Lematizar tokens tras limpieza y convertidos los sinónimos
clean_tokens_sin_lem = []
separator = ' '
for token in nlp(separator.join(clean_tokens_sin_lem)): #Se juntan los tokens en una string, string es el formato necesario para nlp
    print(token.text, token.lemma_, token.pos_)
    clean_tokens_sin_lem.append(token.lemma_)

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin_lem = nltk.FreqDist(clean_tokens_sin)
for key, val in freq_clean_sin_lem.items():
    print (str(key) + ':' + str(val))
# Out:
# finanzas:56
# wikipedia:9
# enciclopedia:2
# libre:1
# function:6
# var:17
# if:1
# cookie:2
# pref:1
# new:1
# regexp:1
# wgbreakframes:1
# false:11
# wgseparatortransformtable:1
# wgdigittransformtable:1
# wgdefaultdateformat:1
# dmy:1
# wgmonthnames:1
# enero:2
# febrero:1
# marzo:1
# abril:3
# mayo:6
# junio:3
# julio:1
# agosto:1
# septiembre:2
# octubre:3
# noviembre:1
# diciembre:1
# wgrequestid:1
# wgcanonicalnamespace:1
# wgcanonicalspecialpagename:1
# wgnamespacenumber:1
# wgpagename:1
# wgtitle:1
# wgcurrevisionid:1
# wgrevisionid:1
# wgarticleid:1
# wgisarticle:1
# true:13
# wgisredirect:1
# wgaction:1
# view:1
# wgusername:1
# null:1
# wgusergroups:1
# wgcategories:1
# artículos:6
# necesitan:2
# referencias:2
# adicionales:2
# referenciar:2
# aún:2
# clasificar:2
# identificadores:4
# lccn:1
# aat:1
# administración:5
# economía:14
# empresa:14
# wgpageviewlanguage:1
# wgpagecontentlanguage:1
# wgpagecontentmodel:1
# wikitext:1
# wgrelevantpagename:1
# ...

# %%
#Visualizar Tokens
freq_clean_sin_lem.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
